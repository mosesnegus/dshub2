# %%
# !pip install google-api-python-client
# Out:
# Collecting google-api-python-client
#   Downloading google_api_python_client-1.6.6-py2.py3-none-any.whl (53kB)
#     100% |████████████████████████████████| 61kB 274kB/s ta 0:00:01
# Requirement already satisfied: six<2dev,>=1.6.1 in /opt/conda/lib/python3.6/site-packages (from google-api-python-client)
# Collecting oauth2client<5.0.0dev,>=1.5.0 (from google-api-python-client)
#   Downloading oauth2client-4.1.2-py2.py3-none-any.whl (99kB)
#     100% |████████████████████████████████| 102kB 714kB/s a 0:00:011
# Collecting uritemplate<4dev,>=3.0.0 (from google-api-python-client)
#   Downloading uritemplate-3.0.0-py2.py3-none-any.whl
# Collecting httplib2<1dev,>=0.9.2 (from google-api-python-client)
#   Downloading httplib2-0.11.3.tar.gz (215kB)
#     100% |████████████████████████████████| 225kB 300kB/s eta 0:00:01
# Collecting pyasn1>=0.1.7 (from oauth2client<5.0.0dev,>=1.5.0->google-api-python-client)
#   Downloading pyasn1-0.4.2-py2.py3-none-any.whl (71kB)
#     100% |████████████████████████████████| 71kB 902kB/s ta 0:00:01
# Collecting pyasn1-modules>=0.0.5 (from oauth2client<5.0.0dev,>=1.5.0->google-api-python-client)
#   Downloading pyasn1_modules-0.2.1-py2.py3-none-any.whl (60kB)
#     100% |████████████████████████████████| 61kB 1.4MB/s eta 0:00:01
# Collecting rsa>=3.1.4 (from oauth2client<5.0.0dev,>=1.5.0->google-api-python-client)
#   Downloading rsa-3.4.2-py2.py3-none-any.whl (46kB)
#     100% |████████████████████████████████| 51kB 605kB/s eta 0:00:01
# Building wheels for collected packages: httplib2
#   Running setup.py bdist_wheel for httplib2 ... done
#   Stored in directory: /home/jovyan/.cache/pip/wheels/b2/79/b1/d8cd8ac7f345b464fb573b46fd1d523a7cd80ba0b778d2692c
# Successfully built httplib2
# Installing collected packages: pyasn1, pyasn1-modules, httplib2, rsa, oauth2client, uritemplate, google-api-python-client
# Successfully installed google-api-python-client-1.6.6 httplib2-0.11.3 oauth2client-4.1.2 pyasn1-0.4.2 pyasn1-modules-0.2.1 rsa-3.4.2 uritemplate-3.0.0
# You are using pip version 9.0.1, however version 9.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip install --upgrade google-auth google-auth-oauthlib google-auth-httplib2
# Out:
# Collecting google-auth
#   Downloading google_auth-1.4.1-py2.py3-none-any.whl (65kB)
#     100% |████████████████████████████████| 71kB 624kB/s ta 0:00:01
# Collecting google-auth-oauthlib
#   Downloading google_auth_oauthlib-0.2.0-py2.py3-none-any.whl
# Collecting google-auth-httplib2
#   Downloading google_auth_httplib2-0.0.3-py2.py3-none-any.whl
# Requirement already up-to-date: rsa>=3.1.4 in /opt/conda/lib/python3.6/site-packages (from google-auth)
# Collecting cachetools>=2.0.0 (from google-auth)
#   Downloading cachetools-2.0.1-py2.py3-none-any.whl
# Requirement already up-to-date: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.6/site-packages (from google-auth)
# Requirement already up-to-date: six>=1.9.0 in /opt/conda/lib/python3.6/site-packages (from google-auth)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib)
#   Downloading requests_oauthlib-0.8.0-py2.py3-none-any.whl
# Requirement already up-to-date: httplib2>=0.9.1 in /opt/conda/lib/python3.6/site-packages (from google-auth-httplib2)
# Requirement already up-to-date: pyasn1>=0.1.3 in /opt/conda/lib/python3.6/site-packages (from rsa>=3.1.4->google-auth)
# Requirement already up-to-date: requests>=2.0.0 in /opt/conda/lib/python3.6/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib)
# Collecting oauthlib>=0.6.2 (from requests-oauthlib>=0.7.0->google-auth-oauthlib)
#   Downloading oauthlib-2.0.7-py2.py3-none-any.whl (124kB)
#     100% |████████████████████████████████| 133kB 518kB/s ta 0:00:01
# Requirement already up-to-date: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib)
# Requirement already up-to-date: idna<2.7,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib)
# Requirement already up-to-date: urllib3<1.23,>=1.21.1 in /opt/conda/lib/python3.6/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib)
# Requirement already up-to-date: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib)
# Installing collected packages: cachetools, google-auth, oauthlib, requests-oauthlib, google-auth-oauthlib, google-auth-httplib2
# Successfully installed cachetools-2.0.1 google-auth-1.4.1 google-auth-httplib2-0.0.3 google-auth-oauthlib-0.2.0 oauthlib-2.0.7 requests-oauthlib-0.8.0
# You are using pip version 9.0.1, however version 9.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
221353387492-bi6jsblimbv13luolbqud15sig62ju09.apps.googleusercontent.com
5uvRoZZvWM1brBU0RkIhoQwA

# %%
# -*- coding: utf-8 -*-

import os

import google.oauth2.credentials

import google_auth_oauthlib.flow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from google_auth_oauthlib.flow import InstalledAppFlow

# The CLIENT_SECRETS_FILE variable specifies the name of a file that contains
# the OAuth 2.0 information for this application, including its client_id and
# client_secret.
CLIENT_SECRETS_FILE = "client_secret.json"

# This OAuth 2.0 access scope allows for full read/write access to the
# authenticated user's account and requires requests to use an SSL connection.
SCOPES = ['https://www.googleapis.com/auth/youtube.force-ssl']
API_SERVICE_NAME = 'youtube'
API_VERSION = 'v3'

def get_authenticated_service():
  flow = InstalledAppFlow.from_client_secrets_file(CLIENT_SECRETS_FILE, SCOPES)
  credentials = flow.run_console()
  return build(API_SERVICE_NAME, API_VERSION, credentials = credentials)

def print_response(response):
  print(response)

# Build a resource based on a list of properties given as key-value pairs.
# Leave properties with empty values out of the inserted resource.
def build_resource(properties):
  resource = {}
  for p in properties:
    # Given a key like "snippet.title", split into "snippet" and "title", where
    # "snippet" will be an object and "title" will be a property in that object.
    prop_array = p.split('.')
    ref = resource
    for pa in range(0, len(prop_array)):
      is_array = False
      key = prop_array[pa]

      # For properties that have array values, convert a name like
      # "snippet.tags[]" to snippet.tags, and set a flag to handle
      # the value as an array.
      if key[-2:] == '[]':
        key = key[0:len(key)-2:]
        is_array = True

      if pa == (len(prop_array) - 1):
        # Leave properties without values out of inserted resource.
        if properties[p]:
          if is_array:
            ref[key] = properties[p].split(',')
          else:
            ref[key] = properties[p]
      elif key not in ref:
        # For example, the property is "snippet.title", but the resource does
        # not yet have a "snippet" object. Create the snippet object here.
        # Setting "ref = ref[key]" means that in the next time through the
        # "for pa in range ..." loop, we will be setting a property in the
        # resource's "snippet" object.
        ref[key] = {}
        ref = ref[key]
      else:
        # For example, the property is "snippet.description", and the resource
        # already has a "snippet" object.
        ref = ref[key]
  return resource

# Remove keyword arguments that are not set
def remove_empty_kwargs(**kwargs):
  good_kwargs = {}
  if kwargs is not None:
    for key, value in kwargs.items():
      if value:
        good_kwargs[key] = value
  return good_kwargs

def playlists_insert(client, properties, **kwargs):
  # See full sample for function
  resource = build_resource(properties)

  # See full sample for function
  kwargs = remove_empty_kwargs(**kwargs)

  response = client.playlists().insert(
    body=resource,
    **kwargs
  ).execute()

  return response


def playlist_items_list_by_playlist_id(client, **kwargs):
  # See full sample for function
  kwargs = remove_empty_kwargs(**kwargs)

  response = client.playlistItems().list(
    **kwargs
  ).execute()

  return response

# %%
# When running locally, disable OAuthlib's HTTPs verification. When
# running in production *do not* leave this option enabled.
os.environ['OAUTHLIB_INSECURE_TRANSPORT'] = '1'
client = get_authenticated_service()
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=221353387492-bi6jsblimbv13luolbqud15sig62ju09.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fyoutube.force-ssl&state=iSXMVM6lIYfrBq6rvpsuljyu736ELf&prompt=consent&access_type=offline
# Enter the authorization code: 4/AABZ4W_T7rJ4ZTUYa9ePOKB9smbcRWdAljm4vELfZHrKAN2I08Fq5PQ

# %%
# Sample python code for playlistItems.list

def playlist_items_list_by_playlist_id(client, **kwargs):
  # See full sample for function
  kwargs = remove_empty_kwargs(**kwargs)

  response = client.playlistItems().list(
    **kwargs
  ).execute()

  return response

# %%
import pandas as pd

# %%
playlist_items_list_by_playlist_id(client,
    part='snippet,contentDetails',
    maxResults=25,
    playlistId='PLAwxTw4SYaPmaHhu-Lz3mhLSj-YH-JnG7')
# Out:
# {'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/qHl8fqkiGLNokol2cL2hmRpenGA"',
#  'items': [{'contentDetails': {'videoId': 'ZIuXdAOhiEg',
#     'videoPublishedAt': '2015-02-23T19:55:08.000Z'},
#    'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/0UU4EreFdUQ3oLveKYa05Fc51ec"',
#    'id': 'UExBd3hUdzRTWWFQbWFIaHUtTHozbWhMU2otWUgtSm5HNy41NkI0NEY2RDEwNTU3Q0M2',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCBVCi5JbYmfG3q5MEuoWdOw',
#     'channelTitle': 'Udacity',
#     'description': "Watch on Udacity: https://www.udacity.com/course/viewer#!/c-ud262/l-521298714/m-534408608\nCheck out the full Advanced Operating Systems course for free at: https://www.udacity.com/course/ud262 \nGeorgia Tech online Master's program: https://www.udacity.com/georgia-tech",
#     'playlistId': 'PLAwxTw4SYaPmaHhu-Lz3mhLSj-YH-JnG7',
#     'position': 0,
#     'publishedAt': '2015-03-24T16:19:14.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'ZIuXdAOhiEg'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/ZIuXdAOhiEg/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/ZIuXdAOhiEg/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/ZIuXdAOhiEg/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/ZIuXdAOhiEg/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/ZIuXdAOhiEg/sddefault.jpg',
#       'width': 640}},
#     'title': 'Optimization - Georgia Tech - Machine Learning'}},
#   {'contentDetails': {'videoId': 'QivAP2g-lcM',
#     'videoPublishedAt': '2015-02-23T19:55:06.000Z'},
#    'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/khX0Sffh3R3KEAPCbtxu7fwgfyA"',
#    'id': 'UExBd3hUdzRTWWFQbWFIaHUtTHozbWhMU2otWUgtSm5HNy4yODlGNEE0NkRGMEEzMEQy',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCBVCi5JbYmfG3q5MEuoWdOw',
#     'channelTitle': 'Udacity',
#     'description': "Watch on Udacity: https://www.udacity.com/course/viewer#!/c-ud262/l-521298714/e-534408609/m-534408610\nCheck out the full Advanced Operating Systems course for free at: https://www.udacity.com/course/ud262 \nGeorgia Tech online Master's program: https://www.udacity.com/georgia-tech",
#     'playlistId': 'PLAwxTw4SYaPmaHhu-Lz3mhLSj-YH-JnG7',
#     'position': 1,
#     'publishedAt': '2015-03-24T16:19:18.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'QivAP2g-lcM'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/QivAP2g-lcM/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/QivAP2g-lcM/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/QivAP2g-lcM/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/QivAP2g-lcM/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/QivAP2g-lcM/sddefault.jpg',
#       'width': 640}},
#     'title': 'Optimize Me Quiz - Georgia Tech - Machine Learning'}},
#   {'contentDetails': {'videoId': 'g7dRd-FL94A',
#     'videoPublishedAt': '2015-02-23T19:55:09.000Z'},
#    'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/VTaxTQ7fBKVdOo85HNizxnqDxuM"',
#    'id': 'UExBd3hUdzRTWWFQbWFIaHUtTHozbWhMU2otWUgtSm5HNy4wMTcyMDhGQUE4NTIzM0Y5',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCBVCi5JbYmfG3q5MEuoWdOw',
#     'channelTitle': 'Udacity',
#     'description': "Watch on Udacity: https://www.udacity.com/course/viewer#!/c-ud262/l-521298714/e-534408609/m-534408612\nCheck out the full Advanced Operating Systems course for free at: https://www.udacity.com/course/ud262 \nGeorgia Tech online Master's program: https://www.udacity.com/georgia-tech",
#     'playlistId': 'PLAwxTw4SYaPmaHhu-Lz3mhLSj-YH-JnG7',
#     'position': 2,
#     'publishedAt': '2015-03-24T16:19:20.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'g7dRd-FL94A'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/g7dRd-FL94A/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/g7dRd-FL94A/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/g7dRd-FL94A/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/g7dRd-FL94A/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/g7dRd-FL94A/sddefault.jpg',
#       'width': 640}},
#     'title': 'Optimize Me Quiz Solution - Georgia Tech - Machine Learning'}},
#   {'contentDetails': {'videoId': 'N5wff4C0--0',
#     'videoPublishedAt': '2015-02-23T19:55:07.000Z'},
#    'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/fl5-XrkRyZQ5oH2I1SQabBLC5Y8"',
#    'id': 'UExBd3hUdzRTWWFQbWFIaHUtTHozbWhMU2otWUgtSm5HNy41MjE1MkI0OTQ2QzJGNzNG',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCBVCi5JbYmfG3q5MEuoWdOw',
#     'channelTitle': 'Udacity',
#     'description': "Watch on Udacity: https://www.udacity.com/course/viewer#!/c-ud262/l-521298714/m-534408613\nCheck out the full Advanced Operating Systems course for free at: https://www.udacity.com/course/ud262 \nGeorgia Tech online Master's program: https://www.udacity.com/georgia-tech",
#     'playlistId': 'PLAwxTw4SYaPmaHhu-Lz3mhLSj-YH-JnG7',
#     'position': 3,
#     'publishedAt': '2015-03-24T16:19:22.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'N5wff4C0--0'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/N5wff4C0--0/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/N5wff4C0--0/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/N5wff4C0--0/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/N5wff4C0--0/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/N5wff4C0--0/sddefault.jpg',
#       'width': 640}},
#     'title': 'Optimization Approaches - Georgia Tech - Machine Learning'}},
#   {'contentDetails': {'videoId': 'kOFBnKDGtJM',
#     'videoPublishedAt': '2015-02-23T19:55:06.000Z'},
#    'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/zx4bbjLWn92wlYMhB2pmUE6RZRA"',
#    'id': 'UExBd3hUdzRTWWFQbWFIaHUtTHozbWhMU2otWUgtSm5HNy4wOTA3OTZBNzVEMTUzOTMy',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCBVCi5JbYmfG3q5MEuoWdOw',
#     'channelTitle': 'Udacity',
#     'description': "Watch on Udacity: https://www.udacity.com/course/viewer#!/c-ud262/l-521298714/m-534408614\nCheck out the full Advanced Operating Systems course for free at: https://www.udacity.com/course/ud262 \nGeorgia Tech online Master's program: https://www.udacity.com/georgia-tech",
#     'playlistId': 'PLAwxTw4SYaPmaHhu-Lz3mhLSj-YH-JnG7',
#     'position': 4,
#     'publishedAt': '2015-03-24T16:19:23.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'kOFBnKDGtJM'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/kOFBnKDGtJM/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/kOFBnKDGtJM/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/kOFBnKDGtJM/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/kOFBnKDGtJM/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/kOFBnKDGtJM/sddefault.jpg',
#       'width': 640}},
#     'title': 'Hill Climbing - Georgia Tech - Machine Learning'}},
#   {'contentDetails': {'videoId': 'Bw4oFUiabXU',
#     'videoPublishedAt': '2015-02-23T19:55:07.000Z'},
#    'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/P3CvnSc5v8-bU8nJa-ZkaOzkedo"',
#    'id': 'UExBd3hUdzRTWWFQbWFIaHUtTHozbWhMU2otWUgtSm5HNy4xMkVGQjNCMUM1N0RFNEUx',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCBVCi5JbYmfG3q5MEuoWdOw',
#     'channelTitle': 'Udacity',
#     'description': "Watch on Udacity: https://www.udacity.com/course/viewer#!/c-ud262/l-521298714/e-534408615/m-534408616\nCheck out the full Advanced Operating Systems course for free at: https://www.udacity.com/course/ud262 \nGeorgia Tech online Master's program: https://www.udacity.com/georgia-tech",
#     'playlistId': 'PLAwxTw4SYaPmaHhu-Lz3mhLSj-YH-JnG7',
#     'position': 5,
#     'publishedAt': '2015-03-24T16:19:25.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'Bw4oFUiabXU'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/Bw4oFUiabXU/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/Bw4oFUiabXU/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/Bw4oFUiabXU/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/Bw4oFUiabXU/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/Bw4oFUiabXU/sddefault.jpg',
#       'width': 640}},
#     'title': 'Guess My Word Quiz - Georgia Tech - Machine Learning'}},
#   {'contentDetails': {'videoId': 'b9QA2ETuhso',
#     'videoPublishedAt': '2015-02-23T19:55:08.000Z'},
#    'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/1zPNJIte1MPkTetxsTM8kKcs3yY"',
#    'id': 'UExBd3hUdzRTWWFQbWFIaHUtTHozbWhMU2otWUgtSm5HNy41MzJCQjBCNDIyRkJDN0VD',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCBVCi5JbYmfG3q5MEuoWdOw',
#     'channelTitle': 'Udacity',
#     'description': "Watch on Udacity: https://www.udacity.com/course/viewer#!/c-ud262/l-521298714/e-534408615/m-534408618\nCheck out the full Advanced Operating Systems course for free at: https://www.udacity.com/course/ud262 \nGeorgia Tech online Master's program: https://www.udacity.com/georgia-tech",
#     'playlistId': 'PLAwxTw4SYaPmaHhu-Lz3mhLSj-YH-JnG7',
#     'position': 6,
#     'publishedAt': '2015-03-24T16:19:28.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'b9QA2ETuhso'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/b9QA2ETuhso/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/b9QA2ETuhso/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/b9QA2ETuhso/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/b9QA2ETuhso/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/b9QA2ETuhso/sddefault.jpg',
#       'width': 640}},
#     'title': 'Guess My Word Quiz Solution - Georgia Tech - Machine Learning'}},
#   {'contentDetails': {'videoId': 'lFjH05v3T54',
#     'videoPublishedAt': '2015-02-23T19:55:10.000Z'},
#    'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/j7TqQZd7zV-mmK2Gsj1ONJKwZPw"',
#    'id': 'UExBd3hUdzRTWWFQbWFIaHUtTHozbWhMU2otWUgtSm5HNy5DQUNERDQ2NkIzRUQxNTY1',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCBVCi5JbYmfG3q5MEuoWdOw',
#     'channelTitle': 'Udacity',
#     'description': "Watch on Udacity: https://www.udacity.com/course/viewer#!/c-ud262/l-521298714/m-534408619\nCheck out the full Advanced Operating Systems course for free at: https://www.udacity.com/course/ud262 \nGeorgia Tech online Master's program: https://www.udacity.com/georgia-tech",
#     'playlistId': 'PLAwxTw4SYaPmaHhu-Lz3mhLSj-YH-JnG7',
#     'position': 7,
#     'publishedAt': '2015-03-24T16:19:30.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'lFjH05v3T54'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/lFjH05v3T54/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/lFjH05v3T54/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/lFjH05v3T54/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/lFjH05v3T54/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/lFjH05v3T54/sddefault.jpg',
#       'width': 640}},
#     'title': 'Random Restart Hill Climbing - Georgia Tech - Machine Learning'}},
#   {'contentDetails': {'videoId': '4PPolJT1gfI',
#     'videoPublishedAt': '2015-02-23T19:55:09.000Z'},
#    'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/qmnfoO2dgKlU1anp_iV2kMvK1wA"',
#    'id': 'UExBd3hUdzRTWWFQbWFIaHUtTHozbWhMU2otWUgtSm5HNy45NDk1REZENzhEMzU5MDQz',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCBVCi5JbYmfG3q5MEuoWdOw',
#     'channelTitle': 'Udacity',
#     'description': "Watch on Udacity: https://www.udacity.com/course/viewer#!/c-ud262/l-521298714/e-534408620/m-534408621\nCheck out the full Advanced Operating Systems course for free at: https://www.udacity.com/course/ud262 \nGeorgia Tech online Master's program: https://www.udacity.com/georgia-tech",
#     'playlistId': 'PLAwxTw4SYaPmaHhu-Lz3mhLSj-YH-JnG7',
#     'position': 8,
#     'publishedAt': '2015-03-24T16:19:33.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': '4PPolJT1gfI'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/4PPolJT1gfI/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/4PPolJT1gfI/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/4PPolJT1gfI/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/4PPolJT1gfI/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/4PPolJT1gfI/sddefault.jpg',
#       'width': 640}},
#     'title': 'Randomized Hill Climbing Quiz - Georgia Tech - Machine Learning'}},
#   {'contentDetails': {'videoId': 'Ts9vLVxyqdY',
#     'videoPublishedAt': '2015-02-23T19:55:14.000Z'},
#    'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/qY4PzZG9fv3PFtK46JJDI53-Ryc"',
#    'id': 'UExBd3hUdzRTWWFQbWFIaHUtTHozbWhMU2otWUgtSm5HNy5GNjNDRDREMDQxOThCMDQ2',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCBVCi5JbYmfG3q5MEuoWdOw',
#     'channelTitle': 'Udacity',
#     'description': "Watch on Udacity: https://www.udacity.com/course/viewer#!/c-ud262/l-521298714/e-534408620/m-534408623\nCheck out the full Advanced Operating Systems course for free at: https://www.udacity.com/course/ud262 \nGeorgia Tech online Master's program: https://www.udacity.com/georgia-tech",
#     'playlistId': 'PLAwxTw4SYaPmaHhu-Lz3mhLSj-YH-JnG7',
#     'position': 9,
#     'publishedAt': '2015-03-24T16:19:34.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'Ts9vLVxyqdY'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/Ts9vLVxyqdY/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/Ts9vLVxyqdY/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/Ts9vLVxyqdY/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/Ts9vLVxyqdY/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/Ts9vLVxyqdY/sddefault.jpg',
#       'width': 640}},
#     'title': 'Randomized Hill Climbing Quiz Quiz Solution - Georgia Tech - Machine Learning'}},
#   {'contentDetails': {'videoId': 'Dp1irQX-c0Q',
#     'videoPublishedAt': '2015-02-23T19:55:10.000Z'},
#    'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/cCF9ZdLwsk5-WNnAo0E9q02w3do"',
#    'id': 'UExBd3hUdzRTWWFQbWFIaHUtTHozbWhMU2otWUgtSm5HNy40NzZCMERDMjVEN0RFRThB',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCBVCi5JbYmfG3q5MEuoWdOw',
#     'channelTitle': 'Udacity',
#     'description': "Watch on Udacity: https://www.udacity.com/course/viewer#!/c-ud262/l-521298714/m-534408624\nCheck out the full Advanced Operating Systems course for free at: https://www.udacity.com/course/ud262 \nGeorgia Tech online Master's program: https://www.udacity.com/georgia-tech",
#     'playlistId': 'PLAwxTw4SYaPmaHhu-Lz3mhLSj-YH-JnG7',
#     'position': 10,
#     'publishedAt': '2015-03-24T16:19:37.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'Dp1irQX-c0Q'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/Dp1irQX-c0Q/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/Dp1irQX-c0Q/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/Dp1irQX-c0Q/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/Dp1irQX-c0Q/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/Dp1irQX-c0Q/sddefault.jpg',
#       'width': 640}},
#     'title': 'Simulated Annealing - Georgia Tech - Machine Learning'}},
#   {'contentDetails': {'videoId': 'K7vc60jn1KU',
#     'videoPublishedAt': '2015-02-23T19:55:11.000Z'},
#    'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/o8EGdTZxhKDrNnW2NY5dgpjHYKk"',
#    'id': 'UExBd3hUdzRTWWFQbWFIaHUtTHozbWhMU2otWUgtSm5HNy5EMEEwRUY5M0RDRTU3NDJC',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCBVCi5JbYmfG3q5MEuoWdOw',
#     'channelTitle': 'Udacity',
#     'description': "Watch on Udacity: https://www.udacity.com/course/viewer#!/c-ud262/l-521298714/m-534408625\nCheck out the full Advanced Operating Systems course for free at: https://www.udacity.com/course/ud262 \nGeorgia Tech online Master's program: https://www.udacity.com/georgia-tech",
#     'playlistId': 'PLAwxTw4SYaPmaHhu-Lz3mhLSj-YH-JnG7',
#     'position': 11,
#     'publishedAt': '2015-03-24T16:19:39.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'K7vc60jn1KU'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/K7vc60jn1KU/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/K7vc60jn1KU/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/K7vc60jn1KU/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/K7vc60jn1KU/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/K7vc60jn1KU/sddefault.jpg',
#       'width': 640}},
#     'title': 'Annealing Algorithm - Georgia Tech - Machine Learning'}},
#   {'contentDetails': {'videoId': 'enNgiWuIHAo',
#     'videoPublishedAt': '2015-02-23T19:55:11.000Z'},
#    'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/XNspBMEg1F4SUxsn276_bh6r3Q8"',
#    'id': 'UExBd3hUdzRTWWFQbWFIaHUtTHozbWhMU2otWUgtSm5HNy45ODRDNTg0QjA4NkFBNkQy',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCBVCi5JbYmfG3q5MEuoWdOw',
#     'channelTitle': 'Udacity',
#     'description': "Watch on Udacity: https://www.udacity.com/course/viewer#!/c-ud262/l-521298714/m-534408626\nCheck out the full Advanced Operating Systems course for free at: https://www.udacity.com/course/ud262 \nGeorgia Tech online Master's program: https://www.udacity.com/georgia-tech",
#     'playlistId': 'PLAwxTw4SYaPmaHhu-Lz3mhLSj-YH-JnG7',
#     'position': 12,
#     'publishedAt': '2015-03-24T16:19:42.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'enNgiWuIHAo'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/enNgiWuIHAo/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/enNgiWuIHAo/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/enNgiWuIHAo/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/enNgiWuIHAo/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/enNgiWuIHAo/sddefault.jpg',
#       'width': 640}},
#     'title': 'Properties of Simulated Annealing - Georgia Tech - Machine Learning'}},
#   {'contentDetails': {'videoId': '9c1qo1eU1kY',
#     'videoPublishedAt': '2015-02-23T19:55:12.000Z'},
#    'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/O-jPBY4DOin3hLBBOr0MO6NXI6w"',
#    'id': 'UExBd3hUdzRTWWFQbWFIaHUtTHozbWhMU2otWUgtSm5HNy4zMDg5MkQ5MEVDMEM1NTg2',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCBVCi5JbYmfG3q5MEuoWdOw',
#     'channelTitle': 'Udacity',
#     'description': "Watch on Udacity: https://www.udacity.com/course/viewer#!/c-ud262/l-521298714/m-534408627\nCheck out the full Advanced Operating Systems course for free at: https://www.udacity.com/course/ud262 \nGeorgia Tech online Master's program: https://www.udacity.com/georgia-tech",
#     'playlistId': 'PLAwxTw4SYaPmaHhu-Lz3mhLSj-YH-JnG7',
#     'position': 13,
#     'publishedAt': '2015-03-24T16:19:46.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': '9c1qo1eU1kY'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/9c1qo1eU1kY/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/9c1qo1eU1kY/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/9c1qo1eU1kY/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/9c1qo1eU1kY/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/9c1qo1eU1kY/sddefault.jpg',
#       'width': 640}},
#     'title': 'Genetic Algorithms - Georgia Tech - Machine Learning'}},
#   {'contentDetails': {'videoId': 'DCnleR_1_rY',
#     'videoPublishedAt': '2015-02-23T19:55:12.000Z'},
#    'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/vZOh7UgRbfmYmhr7vO0fOpWQZJE"',
#    'id': 'UExBd3hUdzRTWWFQbWFIaHUtTHozbWhMU2otWUgtSm5HNy41Mzk2QTAxMTkzNDk4MDhF',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCBVCi5JbYmfG3q5MEuoWdOw',
#     'channelTitle': 'Udacity',
#     'description': "Watch on Udacity: https://www.udacity.com/course/viewer#!/c-ud262/l-521298714/m-534408628\nCheck out the full Advanced Operating Systems course for free at: https://www.udacity.com/course/ud262 \nGeorgia Tech online Master's program: https://www.udacity.com/georgia-tech",
#     'playlistId': 'PLAwxTw4SYaPmaHhu-Lz3mhLSj-YH-JnG7',
#     'position': 14,
#     'publishedAt': '2015-03-24T16:19:48.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'DCnleR_1_rY'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/DCnleR_1_rY/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/DCnleR_1_rY/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/DCnleR_1_rY/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/DCnleR_1_rY/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/DCnleR_1_rY/sddefault.jpg',
#       'width': 640}},
#     'title': 'GA Skeleton - Georgia Tech - Machine Learning'}},
#   {'contentDetails': {'videoId': 'gGaD1hEvDHM',
#     'videoPublishedAt': '2015-02-23T19:55:13.000Z'},
#    'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/tkHWdHdVsshi9LkHrB6z8ksiYq4"',
#    'id': 'UExBd3hUdzRTWWFQbWFIaHUtTHozbWhMU2otWUgtSm5HNy5EQUE1NTFDRjcwMDg0NEMz',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCBVCi5JbYmfG3q5MEuoWdOw',
#     'channelTitle': 'Udacity',
#     'description': "Watch on Udacity: https://www.udacity.com/course/viewer#!/c-ud262/l-521298714/m-534408629\nCheck out the full Advanced Operating Systems course for free at: https://www.udacity.com/course/ud262 \nGeorgia Tech online Master's program: https://www.udacity.com/georgia-tech",
#     'playlistId': 'PLAwxTw4SYaPmaHhu-Lz3mhLSj-YH-JnG7',
#     'position': 15,
#     'publishedAt': '2015-03-24T16:19:50.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'gGaD1hEvDHM'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/gGaD1hEvDHM/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/gGaD1hEvDHM/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/gGaD1hEvDHM/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/gGaD1hEvDHM/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/gGaD1hEvDHM/sddefault.jpg',
#       'width': 640}},
#     'title': 'Crossover Example - Georgia Tech - Machine Learning'}},
#   {'contentDetails': {'videoId': '_4rMdZt_DOI',
#     'videoPublishedAt': '2015-02-23T19:55:13.000Z'},
#    'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/T-KOPdT-QainfMezABdyHVqPizs"',
#    'id': 'UExBd3hUdzRTWWFQbWFIaHUtTHozbWhMU2otWUgtSm5HNy41QTY1Q0UxMTVCODczNThE',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCBVCi5JbYmfG3q5MEuoWdOw',
#     'channelTitle': 'Udacity',
#     'description': "Watch on Udacity: https://www.udacity.com/course/viewer#!/c-ud262/l-521298714/m-534408630\nCheck out the full Advanced Operating Systems course for free at: https://www.udacity.com/course/ud262 \nGeorgia Tech online Master's program: https://www.udacity.com/georgia-tech",
#     'playlistId': 'PLAwxTw4SYaPmaHhu-Lz3mhLSj-YH-JnG7',
#     'position': 16,
#     'publishedAt': '2015-03-24T16:19:52.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': '_4rMdZt_DOI'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/_4rMdZt_DOI/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/_4rMdZt_DOI/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/_4rMdZt_DOI/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/_4rMdZt_DOI/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/_4rMdZt_DOI/sddefault.jpg',
#       'width': 640}},
#     'title': 'What Have We Learned - Georgia Tech - Machine Learning'}},
#   {'contentDetails': {'videoId': 'HNXejaW3LiU',
#     'videoPublishedAt': '2015-02-23T19:56:08.000Z'},
#    'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/KY8-VYCvwpCd4ikfpED5Xu-jKKQ"',
#    'id': 'UExBd3hUdzRTWWFQbWFIaHUtTHozbWhMU2otWUgtSm5HNy4yMUQyQTQzMjRDNzMyQTMy',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCBVCi5JbYmfG3q5MEuoWdOw',
#     'channelTitle': 'Udacity',
#     'description': "Watch on Udacity: https://www.udacity.com/course/viewer#!/c-ud262/l-521298714/m-616628565\nCheck out the full Advanced Operating Systems course for free at: https://www.udacity.com/course/ud262 \nGeorgia Tech online Master's program: https://www.udacity.com/georgia-tech",
#     'playlistId': 'PLAwxTw4SYaPmaHhu-Lz3mhLSj-YH-JnG7',
#     'position': 17,
#     'publishedAt': '2015-03-24T16:19:54.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'HNXejaW3LiU'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/HNXejaW3LiU/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/HNXejaW3LiU/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/HNXejaW3LiU/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/HNXejaW3LiU/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/HNXejaW3LiU/sddefault.jpg',
#       'width': 640}},
#     'title': 'MIMIC - Georgia Tech - Machine Learning'}},
#   {'contentDetails': {'videoId': 'L3a7FClt1UY',
#     'videoPublishedAt': '2015-02-23T19:56:08.000Z'},
#    'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/P1toBun2_91U6L2csYvIoYh4qcc"',
#    'id': 'UExBd3hUdzRTWWFQbWFIaHUtTHozbWhMU2otWUgtSm5HNy45RTgxNDRBMzUwRjQ0MDhC',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCBVCi5JbYmfG3q5MEuoWdOw',
#     'channelTitle': 'Udacity',
#     'description': "Watch on Udacity: https://www.udacity.com/course/viewer#!/c-ud262/l-521298714/e-616628566/m-616628567\nCheck out the full Advanced Operating Systems course for free at: https://www.udacity.com/course/ud262 \nGeorgia Tech online Master's program: https://www.udacity.com/georgia-tech",
#     'playlistId': 'PLAwxTw4SYaPmaHhu-Lz3mhLSj-YH-JnG7',
#     'position': 18,
#     'publishedAt': '2015-03-24T16:19:55.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'L3a7FClt1UY'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/L3a7FClt1UY/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/L3a7FClt1UY/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/L3a7FClt1UY/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/L3a7FClt1UY/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/L3a7FClt1UY/sddefault.jpg',
#       'width': 640}},
#     'title': 'A Probability Model Quiz - Georgia Tech - Machine Learning'}},
#   {'contentDetails': {'videoId': '49Y2C_mTWD0',
#     'videoPublishedAt': '2015-02-23T19:56:08.000Z'},
#    'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/raN9qmczCG8eMw_WaH8iCCUK0EQ"',
#    'id': 'UExBd3hUdzRTWWFQbWFIaHUtTHozbWhMU2otWUgtSm5HNy5ENDU4Q0M4RDExNzM1Mjcy',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCBVCi5JbYmfG3q5MEuoWdOw',
#     'channelTitle': 'Udacity',
#     'description': "Watch on Udacity: https://www.udacity.com/course/viewer#!/c-ud262/l-521298714/e-616628566/m-616628569\nCheck out the full Advanced Operating Systems course for free at: https://www.udacity.com/course/ud262 \nGeorgia Tech online Master's program: https://www.udacity.com/georgia-tech",
#     'playlistId': 'PLAwxTw4SYaPmaHhu-Lz3mhLSj-YH-JnG7',
#     'position': 19,
#     'publishedAt': '2015-03-24T16:19:57.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': '49Y2C_mTWD0'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/49Y2C_mTWD0/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/49Y2C_mTWD0/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/49Y2C_mTWD0/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/49Y2C_mTWD0/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/49Y2C_mTWD0/sddefault.jpg',
#       'width': 640}},
#     'title': 'A Probability Model Quiz Solution - Georgia Tech - Machine Learning'}},
#   {'contentDetails': {'videoId': 'mGmCYBoI0Dg',
#     'videoPublishedAt': '2015-02-23T19:56:08.000Z'},
#    'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/gRmRCBM0yMZ1OWHTX18UUSzs-Hk"',
#    'id': 'UExBd3hUdzRTWWFQbWFIaHUtTHozbWhMU2otWUgtSm5HNy4yMDhBMkNBNjRDMjQxQTg1',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCBVCi5JbYmfG3q5MEuoWdOw',
#     'channelTitle': 'Udacity',
#     'description': "Watch on Udacity: https://www.udacity.com/course/viewer#!/c-ud262/l-521298714/m-616628570\nCheck out the full Advanced Operating Systems course for free at: https://www.udacity.com/course/ud262 \nGeorgia Tech online Master's program: https://www.udacity.com/georgia-tech",
#     'playlistId': 'PLAwxTw4SYaPmaHhu-Lz3mhLSj-YH-JnG7',
#     'position': 20,
#     'publishedAt': '2015-03-24T16:19:58.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'mGmCYBoI0Dg'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/mGmCYBoI0Dg/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/mGmCYBoI0Dg/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/mGmCYBoI0Dg/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/mGmCYBoI0Dg/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/mGmCYBoI0Dg/sddefault.jpg',
#       'width': 640}},
#     'title': 'Pseudo Code - Georgia Tech - Machine Learning'}},
#   {'contentDetails': {'videoId': 'QPDIZJbgfwA',
#     'videoPublishedAt': '2015-02-23T19:56:09.000Z'},
#    'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/TPB5WqmxGHTQLYdjnb0Kc3iI6fs"',
#    'id': 'UExBd3hUdzRTWWFQbWFIaHUtTHozbWhMU2otWUgtSm5HNy5GM0Q3M0MzMzY5NTJFNTdE',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCBVCi5JbYmfG3q5MEuoWdOw',
#     'channelTitle': 'Udacity',
#     'description': "Watch on Udacity: https://www.udacity.com/course/viewer#!/c-ud262/l-521298714/m-616628571\nCheck out the full Advanced Operating Systems course for free at: https://www.udacity.com/course/ud262 \nGeorgia Tech online Master's program: https://www.udacity.com/georgia-tech",
#     'playlistId': 'PLAwxTw4SYaPmaHhu-Lz3mhLSj-YH-JnG7',
#     'position': 21,
#     'publishedAt': '2015-03-24T16:20:04.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'QPDIZJbgfwA'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/QPDIZJbgfwA/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/QPDIZJbgfwA/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/QPDIZJbgfwA/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/QPDIZJbgfwA/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/QPDIZJbgfwA/sddefault.jpg',
#       'width': 640}},
#     'title': 'Estimating Distributions - Georgia Tech - Machine Learning'}},
#   {'contentDetails': {'videoId': 'R-Mf9-tKC5o',
#     'videoPublishedAt': '2015-02-23T19:56:08.000Z'},
#    'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/UyeVVH1_IB7VouJ8wGH1jlZ5QSY"',
#    'id': 'UExBd3hUdzRTWWFQbWFIaHUtTHozbWhMU2otWUgtSm5HNy4zRjM0MkVCRTg0MkYyQTM0',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCBVCi5JbYmfG3q5MEuoWdOw',
#     'channelTitle': 'Udacity',
#     'description': "Watch on Udacity: https://www.udacity.com/course/viewer#!/c-ud262/l-521298714/m-616628572\nCheck out the full Advanced Operating Systems course for free at: https://www.udacity.com/course/ud262 \nGeorgia Tech online Master's program: https://www.udacity.com/georgia-tech",
#     'playlistId': 'PLAwxTw4SYaPmaHhu-Lz3mhLSj-YH-JnG7',
#     'position': 22,
#     'publishedAt': '2015-03-24T16:20:08.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'R-Mf9-tKC5o'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/R-Mf9-tKC5o/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/R-Mf9-tKC5o/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/R-Mf9-tKC5o/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/R-Mf9-tKC5o/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/R-Mf9-tKC5o/sddefault.jpg',
#       'width': 640}},
#     'title': 'Finding Dependency Trees - Georgia Tech - Machine Learning'}},
#   {'contentDetails': {'videoId': 'u2V7esTMhKc',
#     'videoPublishedAt': '2015-02-23T19:56:08.000Z'},
#    'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/ZBYIMM3K_qvLg5DXQtzZhlSP6pQ"',
#    'id': 'UExBd3hUdzRTWWFQbWFIaHUtTHozbWhMU2otWUgtSm5HNy45NzUwQkI1M0UxNThBMkU0',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCBVCi5JbYmfG3q5MEuoWdOw',
#     'channelTitle': 'Udacity',
#     'description': "Watch on Udacity: https://www.udacity.com/course/viewer#!/c-ud262/l-521298714/m-616628573\nCheck out the full Advanced Operating Systems course for free at: https://www.udacity.com/course/ud262 \nGeorgia Tech online Master's program: https://www.udacity.com/georgia-tech",
#     'playlistId': 'PLAwxTw4SYaPmaHhu-Lz3mhLSj-YH-JnG7',
#     'position': 23,
#     'publishedAt': '2015-03-24T16:20:13.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'u2V7esTMhKc'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/u2V7esTMhKc/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/u2V7esTMhKc/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/u2V7esTMhKc/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/u2V7esTMhKc/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/u2V7esTMhKc/sddefault.jpg',
#       'width': 640}},
#     'title': 'Finding Dependency Trees Two - Georgia Tech - Machine Learning'}},
#   {'contentDetails': {'videoId': 'rCxGiKQoe4w',
#     'videoPublishedAt': '2015-02-23T19:56:08.000Z'},
#    'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/gCkqAsJ2yMon8JrGdCbl05iqFbQ"',
#    'id': 'UExBd3hUdzRTWWFQbWFIaHUtTHozbWhMU2otWUgtSm5HNy5DNzE1RjZEMUZCMjA0RDBB',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCBVCi5JbYmfG3q5MEuoWdOw',
#     'channelTitle': 'Udacity',
#     'description': "Watch on Udacity: https://www.udacity.com/course/viewer#!/c-ud262/l-521298714/m-616628574\nCheck out the full Advanced Operating Systems course for free at: https://www.udacity.com/course/ud262 \nGeorgia Tech online Master's program: https://www.udacity.com/georgia-tech",
#     'playlistId': 'PLAwxTw4SYaPmaHhu-Lz3mhLSj-YH-JnG7',
#     'position': 24,
#     'publishedAt': '2015-03-24T16:20:16.000Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'rCxGiKQoe4w'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/rCxGiKQoe4w/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/rCxGiKQoe4w/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/rCxGiKQoe4w/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/rCxGiKQoe4w/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/rCxGiKQoe4w/sddefault.jpg',
#       'width': 640}},
#     'title': 'Finding Dependency Trees Three - Georgia Tech - Machine Learning'}}],
#  'kind': 'youtube#playlistItemListResponse',
#  'nextPageToken': 'CBkQAA',
#  'pageInfo': {'resultsPerPage': 25, 'totalResults': 108}}

# %%
resp = playlist_items_list_by_playlist_id(client,
    part='snippet,contentDetails',
    maxResults=25,
    playlistId='PLR3z_fOlGTXJHKOiYz-EAU2NfKYvksYml')

# %%
client.

# %%
pd.DataFrame(resp['items'])
# Out:
#                                       contentDetails  \
# 0  {'videoId': 'K8flPqRAto8', 'videoPublishedAt':...
# 1  {'videoId': 'E1xlTG_Bp4I', 'videoPublishedAt':...
# 2  {'videoId': 'CpGZdwJTgQw', 'videoPublishedAt':...
# 3  {'videoId': 'lg1Uk6nx7Yc', 'videoPublishedAt':...
# 4  {'videoId': '35bwH8hV6UU', 'videoPublishedAt':...
# 5  {'videoId': 'BrrjYJpOxhw', 'videoPublishedAt':...
# 6  {'videoId': 'fyDFhDm8EwU', 'videoPublishedAt':...
# 7  {'videoId': 'i1CtzjojR1c', 'videoPublishedAt':...
#
#                                                 etag  \
# 0  "RmznBCICv9YtgWaaa_nWDIH1_GM/o_ydhEBOpbX96DvN6...
# 1  "RmznBCICv9YtgWaaa_nWDIH1_GM/elu4iocWY7kya5QMf...
# 2  "RmznBCICv9YtgWaaa_nWDIH1_GM/gl1aRHwOsxjREZWsw...
# 3  "RmznBCICv9YtgWaaa_nWDIH1_GM/JJKWMZmnjUstW6Vx4...
# 4  "RmznBCICv9YtgWaaa_nWDIH1_GM/3-amTNrzXU2_CvoW4...
# 5  "RmznBCICv9YtgWaaa_nWDIH1_GM/tFgNByZfNjBs8aoME...
# 6  "RmznBCICv9YtgWaaa_nWDIH1_GM/iam4GBlvANRtT853w...
# 7  "RmznBCICv9YtgWaaa_nWDIH1_GM/OhyKJ-nMV4We45Gbu...
#
#                                                   id                  kind  \
# 0  UExSM3pfZk9sR1RYSkhLT2lZei1FQVUyTmZLWXZrc1ltbC...  youtube#playlistItem
# 1  UExSM3pfZk9sR1RYSkhLT2lZei1FQVUyTmZLWXZrc1ltbC...  youtube#playlistItem
# 2  UExSM3pfZk9sR1RYSkhLT2lZei1FQVUyTmZLWXZrc1ltbC...  youtube#playlistItem
# 3  UExSM3pfZk9sR1RYSkhLT2lZei1FQVUyTmZLWXZrc1ltbC...  youtube#playlistItem
# 4  UExSM3pfZk9sR1RYSkhLT2lZei1FQVUyTmZLWXZrc1ltbC...  youtube#playlistItem
# 5  UExSM3pfZk9sR1RYSkhLT2lZei1FQVUyTmZLWXZrc1ltbC...  youtube#playlistItem
# 6  UExSM3pfZk9sR1RYSkhLT2lZei1FQVUyTmZLWXZrc1ltbC...  youtube#playlistItem
# 7  UExSM3pfZk9sR1RYSkhLT2lZei1FQVUyTmZLWXZrc1ltbC...  youtube#playlistItem
#
#                                              snippet
# 0  {'publishedAt': '2018-01-14T18:39:14.000Z', 'c...
# 1  {'publishedAt': '2018-01-14T19:00:15.000Z', 'c...
# 2  {'publishedAt': '2018-01-14T20:19:10.000Z', 'c...
# 3  {'publishedAt': '2018-01-15T18:35:59.000Z', 'c...
# 4  {'publishedAt': '2018-01-15T19:03:38.000Z', 'c...
# 5  {'publishedAt': '2018-01-15T19:34:32.000Z', 'c...
# 6  {'publishedAt': '2018-01-15T20:24:17.000Z', 'c...
# 7  {'publishedAt': '2018-01-15T21:49:02.000Z', 'c...

# %%
pd.DataFrame(resp)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-2eeba4c9947d> in <module>()
# ----> 1 pd.DataFrame(resp)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     264                                  dtype=dtype, copy=copy)
#     265         elif isinstance(data, dict):
# --> 266             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     267         elif isinstance(data, ma.MaskedArray):
#     268             import numpy.ma.mrecords as mrecords
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     400             arrays = [data[k] for k in keys]
#     401
# --> 402         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     403
#     404     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    5396     # figure out the index, if necessary
#    5397     if index is None:
# -> 5398         index = extract_index(arrays)
#    5399     else:
#    5400         index = _ensure_index(index)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in extract_index(data)
#    5447
#    5448             if have_dicts:
# -> 5449                 raise ValueError('Mixing dicts with non-Series may lead to '
#    5450                                  'ambiguous ordering.')
#    5451
#
# ValueError: Mixing dicts with non-Series may lead to ambiguous ordering.

# %%
playlists_insert(client, 
{'snippet.title': '',
 'snippet.description': '',
 'snippet.tags[]': '',
 'snippet.defaultLanguage': '',
 'status.privacyStatus': ''},
part='snippet,status',
onBehalfOfContentOwner='')
